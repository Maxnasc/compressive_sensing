# %% [markdown]
# ## Verificar características de Phi

# %%
import numpy as np
import matplotlib.pyplot as plt

# Carregando para inspeção
phi = np.load("/mnt/HD/Mestrado/Dissertacao/compressive_sensing/compressed_data_classification/src/cs/cs_constants/cs_best_result_Phi.npy")

print(f"Dimensões (Shape): {phi.shape}") # Deve retornar (50, 100) 
print(f"Tipo de dado: {phi.dtype}")        # Deve ser float64 ou <f8 
print(f"Número de elementos: {phi.size}")

valores_unicos = np.unique(phi)
print(f"Valores únicos na matriz: {valores_unicos}")

# Se for uma matriz de seleção, a soma de cada linha deve ser 1.0
soma_por_linha = np.sum(phi, axis=1)
print(f"Soma das linhas (primeiras 5): {soma_por_linha[:5]}")
